# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# Yes, we can create a Bokeh plot using Python code.

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()

from bokeh.plotting import figure ,output_file , show
from bokeh.sampledata.iris import flowers

output_file('result.html')

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# Glyphs are the 'basic visual building blocks of Bokeh plots' and refer to vectorised graphical shapes or markers that are used to represent your data.

# %%
p=figure(width=400, height=400)

x=[1,2,3,4,5]
y=[6,7,2,4,5]

p.star(x,y,size=20, color='red', alpha=0.9)
show(p)
# Out:
#   <div class="bk-root" id="dffcfd0c-5bc3-465b-a2f3-136964544380" data-root-id="2109"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
p=figure(title="Scatter Plot")
p.scatter(x,y, color='red', legend_label='red points', size=15)
p.xaxis.axis_label = "x axis"
p.yaxis.axis_label = "y axis"
show(p)
# Out:
#   <div class="bk-root" id="1632fdca-2df7-4045-81ed-74787249cf35" data-root-id="2781"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# Bokeh server makes it easy to create interactive web applications that connect front-end UI events to running Python code. Bokeh creates high-level Python models, such as plots, ranges, axes, and glyphs, and then converts these objects to JSON to pass them to its client library, BokehJS.

# %%
from bokeh.io import curdoc
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import Slider, TextInput
from bokeh.plotting import figure
N = 200
x = np.linspace(0, 4*np.pi, N)
y = np.sin(x)
source = ColumnDataSource(data = dict(x = x, y = y))
plot = figure(height=400, width=400, title="sine wave")
plot.line('x', 'y', source = source, line_width = 3, line_alpha = 0.6)
freq = Slider(title = "frequency", value = 1.0, start = 0.1, end = 5.1, step = 0.1)
def update_data(attrname, old, new):
   a = 1
   b = 0
   w = 0
   k = freq.value
   x = np.linspace(0, 4*np.pi, N)
   y = a*np.sin(k*x + w) + b
   source.data = dict(x = x, y = y)
freq.on_change('value', update_data)
curdoc().add_root(row(freq, plot, width = 500))
curdoc().title = "Sliders"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# Bokeh is a data visualization library in Python that provides high-performance interactive charts and plots. Bokeh output can be obtained in various mediums like notebook, html and server. It is possible to embed bokeh plots in Django and flask apps.

# %% [markdown]
# I have created this. My Github link is - https://github.com/arnab031/responsive_chart_with_flask
