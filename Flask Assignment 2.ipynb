# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# GET is used to request data from a specified resource. We send data in parameters for GET method.
#
# POST is used to send data to a server to create/update a resource. We send data in body for POST method.

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
# The Request, in Flask, is an object that contains all the data sent from the Client to Server. This data can be recovered using the GET/POST Methods.

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# Redirection in Flask can be done by returning a redirect response object, created by invoking the redirect() function. The same method is used for redirecting to other routes on the same application and external websites.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered with specific data to produce a final document. Flask uses the Jinja template library to render templates. In our application, we will use templates to render HTML which will display in the user's browser.

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, jsonify, request
from flask import *

app = Flask(__name__)

@app.route("/welcome", methods=["POST"])
def welcome():
    name = request.json['name']
    result = "Welcome "+name+" !!"
    return jsonify(result)

@app.route("/")
def details():
    return redirect(url_for("welcome"))

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:f75ea29c-7900-4730-bfa9-f7a2aacb923a.png)
