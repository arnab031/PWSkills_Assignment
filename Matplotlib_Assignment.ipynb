# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# Matplotlib is used to create 2D or 3D graphs and plots by using python scripts. It has a module named pyplot which makes things easy for plotting by providing feature to control line styles, font properties, formatting axes etc.
#
# Line Plot, Bar Chart Plot, Area Plot, Pie Plot, Scatter Plot can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %% [markdown]
# Dot-based plotting of multiple variables along x and y axes represents a scatter plot. We can use different colors for different bikes if necessary for better plotting and identification of dots.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
print(x)
print(y)
# Out:
# [ 6.57725695  3.8730197   3.19299494 -0.72698541  2.44522359  2.29048204
#   2.83451704  1.74599865  2.91236366  2.04556394  0.37227049  4.76924476
#   4.76263608  6.41914613  3.10006728  2.19064517  1.9092801  -0.09295463
#   4.96473487  0.79786474  0.62990695  2.5887002   5.97229671  3.47343253
#   0.95242972  1.5740136   4.25048993  2.67897327  1.4623273   2.53993856
#   4.49011253  6.95222157  0.51175334  1.74716618  1.39246781 -1.83816635
#   1.15241596  0.95224848  5.24795592  2.73617153 -0.24657089  4.2933509
#   2.28745848 -0.48628207  1.80670072  1.82281124  1.2522354   3.05942763
#  -1.49651554  2.46447627]
# [ 5.02636688  4.70559568  5.216375    5.23878131  5.97508626  0.76339863
#   4.69166681 -0.72177906  1.79422979 -0.82894409  5.09629502  5.66747564
#   2.60517064  6.54929006  1.65054498  3.30123373  3.30589141  0.87160945
#   3.87589322  6.87795692  0.95013825  4.79867689  2.6909863   6.53925461
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y')
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
#     Use the following data:
#     import numpy as np
#     For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#     For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#     For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#     For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# subplot divides the current figure into rectangular panes that are numbered row-wise. Each pane contains an axes. Subsequent plots are output to the current pane.
#
# subplot(m,n,p) creates an axes in the p-th pane of a figure divided into an m-by-n matrix of rectangular panes.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2,2,1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2,2,2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2,2,3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,4)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically.
#
# A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
fig = plt.figure(figsize=(10,5))

plt.bar(company,profit,width=0.4)

plt.xlabel("Company")
plt.ylabel("Profit")
plt.title("Company vs Profit")
plt.show()

# %%
fig = plt.figure(figsize=(10,5))

plt.barh(company,profit)

plt.ylabel("Company")
plt.xlabel("Profit")
plt.title("Company vs Profit")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
#     box1 = np.random.normal(100, 10, 200)
#     box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# A box plot which is also known as a whisker plot displays a summary of a set of data containing the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
# print(box1)
# print(box2)

# %%
data = [box1, box2]
fig = plt.figure(figsize=(10,7))


# Creating axes instance
ax = fig.add_axes([0,0,1,1])

# Creating plot
#plt.boxplot(data)
bp = ax.boxplot(data)

# Show plot 
plt.show()
